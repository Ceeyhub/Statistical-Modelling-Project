# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
# imports
import requests
import os
import pandas as pd
apikey = os.environ['FOURSQUARE_API']
from pprint import pprint

# %%
#citybikes
#Retrieving data for Mantova, Italy
def get_city(city_name):
    url = "http://api.citybik.es/v2/networks/" + city_name
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        return None

# %%
city_name = "mantova"
city_json = get_city(city_name)
if city_json is not None:
    pprint(city_json)
else:
    print("failed to get city JSON")
# Out:
# {'network': {'company': ['Comunicare S.r.l.'],
#              'href': '/v2/networks/bicincitta-mantova',
#              'id': 'bicincitta-mantova',
#              'location': {'city': 'Mantova',
#                           'country': 'IT',
#                           'latitude': 45.15866370764634,
#                           'longitude': 10.783718973016335},
#              'name': 'Bicincittà',
#              'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=204',
#              'stations': [{'empty_slots': 0,
#                            'extra': {'number': 1,
#                                      'reviews': 7,
#                                      'score': 3.7,
#                                      'status': 'offline',
#                                      'uid': '1310'},
#                            'free_bikes': 0,
#                            'id': '9be01b509184baee960fcffa4f1425d3',
#                            'latitude': 45.15866370764634,
#                            'longitude': 10.783718973016335,
#                            'name': 'Stazione FF.SS.',
#                            'timestamp': '2023-08-02T22:51:07.196000Z'},
#                           {'empty_slots': 0,
#                            'extra': {'number': 2,
#                                      'reviews': 1,
#                                      'score': 1.0,
#                                      'status': 'offline',
#                                      'uid': '1311'},
#                            'free_bikes': 0,
#                            'id': '2eb2a00e80e5d6fee19b932294a08927',
#                            'latitude': 45.14750544645031,
#                            'longitude': 10.795176265606642,
#                            'name': 'Porta Cerese',
#                            'timestamp': '2023-08-02T22:51:07.197000Z'},
#                           {'empty_slots': 0,
#                            'extra': {'number': 3,
#                                      'reviews': 1,
#                                      'score': 1.0,
#                                      'status': 'offline',
#                                      'uid': '1312'},
#                            'free_bikes': 0,
#                            'id': 'f2703a28d2f9f3a0e4078867966d4536',
#                            'latitude': 45.162055713921475,
#                            'longitude': 10.811605481588344,
#                            'name': 'Campo Canoa',
#                            'timestamp': '2023-08-02T22:51:07.197000Z'},
#                           {'empty_slots': 0,
#                            'extra': {'number': 4,
#                                      'reviews': 1,
#                                      'score': 1.0,
#                                      'status': 'offline',
#                                      'uid': '1313'},
#                            'free_bikes': 0,
#                            'id': '2fd7039e15452a7a09b5ddca816a6375',
#                            'latitude': 45.157558256082055,
#                            'longitude': 10.794851150331851,
#                            'name': 'Castiglioni',
#                            'timestamp': '2023-08-02T22:51:07.197000Z'},
#                           {'empty_slots': 8,
#                            'extra': {'number': 5,
#                                      'reviews': 1,
#                                      'score': 1.0,
#                                      'status': 'offline',
#                                      'uid': '1314'},
#                            'free_bikes': 0,
#                            'id': 'a97d2eb0b413d91a627e8e661356471b',
#                            'latitude': 45.15356718540835,
#                            'longitude': 10.797891219643361,
#                            'name': 'Anconetta',
#                            'timestamp': '2023-08-02T22:51:07.197000Z'},
#                           {'empty_slots': 0,
#                            'extra': {'number': 6,
#                                      'reviews': 2,
#                                      'score': 2.9,
#                                      'status': 'offline',
#                                      'uid': '1315'},
#                            'free_bikes': 0,
#                            'id': '388ea79ccc1898766848156901c20c1b',
#                            'latitude': 45.157522443543556,
#                            'longitude': 10.790304102238451,
#                            'name': 'Umberto I',
#                            'timestamp': '2023-08-02T22:51:07.197000Z'},
#                           {'empty_slots': 0,
#                            'extra': {'number': 7,
#                                      'reviews': 3,
#                                      'score': 2.0,
#                                      'status': 'offline',
#                                      'uid': '1316'},
#                            'free_bikes': 0,
#                            'id': '5cd1352f5e895893f577ceba80c0bd41',
#                            'latitude': 45.162354679001666,
#                            'longitude': 10.798728486530308,
#                            'name': 'Castello S. Giorgio',
#                            'timestamp': '2023-08-02T22:51:07.197000Z'},
#                           {'empty_slots': 0,
#                            'extra': {'number': 8,
#                                      'reviews': 1,
#                                      'score': 1.0,
#                                      'status': 'offline',
#                                      'uid': '1499'},
#                            'free_bikes': 0,
#                            'id': '43b4d9fcbb4e5b825350b3e43e9941af',
#                            'latitude': 45.150071995246186,
#                            'longitude': 10.786766586122098,
#                            'name': 'Palazzo Te',
#                            'timestamp': '2023-08-02T22:51:07.197000Z'}]}}

# %%
data = response.json

# %%
# Check if city_json contains the 'network' key before extracting stations
if 'network' in city_json:
    stations = city_json['network'].get('stations', [])  # station list, or an empty list if not present
    
    
    if stations:
        # Flatten the stations data
        flattened_stations = pd.json_normalize(stations)

        # Create a DataFrame from the flattened data
        df1 = pd.DataFrame(flattened_stations)

        # Display the DataFrame
        pd.set_option('display.max_columns', None)
        pd.set_option('display.max_rows', None)
        print(df1)
    else:
        print("No stations found for this city.")
else:
    print("City data not available.")
# Out:
#    empty_slots  free_bikes                                id   latitude  \
# 0            0           0  9be01b509184baee960fcffa4f1425d3  45.158664
# 1            0           0  2eb2a00e80e5d6fee19b932294a08927  45.147505
# 2            0           0  f2703a28d2f9f3a0e4078867966d4536  45.162056
# 3            0           0  2fd7039e15452a7a09b5ddca816a6375  45.157558
# 4            8           0  a97d2eb0b413d91a627e8e661356471b  45.153567
# 5            0           0  388ea79ccc1898766848156901c20c1b  45.157522
# 6            0           0  5cd1352f5e895893f577ceba80c0bd41  45.162355
# 7            0           0  43b4d9fcbb4e5b825350b3e43e9941af  45.150072
#
#    longitude                 name                    timestamp  extra.number  \
# 0  10.783719      Stazione FF.SS.  2023-08-02T22:51:07.196000Z             1
# 1  10.795176         Porta Cerese  2023-08-02T22:51:07.197000Z             2
# 2  10.811605          Campo Canoa  2023-08-02T22:51:07.197000Z             3
# 3  10.794851          Castiglioni  2023-08-02T22:51:07.197000Z             4
# 4  10.797891            Anconetta  2023-08-02T22:51:07.197000Z             5
# 5  10.790304            Umberto I  2023-08-02T22:51:07.197000Z             6
# 6  10.798728  Castello S. Giorgio  2023-08-02T22:51:07.197000Z             7
# 7  10.786767           Palazzo Te  2023-08-02T22:51:07.197000Z             8
#
#    extra.reviews  extra.score extra.status extra.uid
# 0              7          3.7      offline      1310
# 1              1          1.0      offline      1311
# 2              1          1.0      offline      1312
# 3              1          1.0      offline      1313
# 4              1          1.0      offline      1314
# 5              2          2.9      offline      1315
# 6              3          2.0      offline      1316
# 7              1          1.0      offline      1499

# %%
#foursquare

url = "https://api.foursquare.com/v3/places/search?query=restaurant&ll=45.15866370764634%2C10.783718973016335&radius=1000"

#url = "https://api.foursquare.com/v3/places/search"
headers = {
    "accept": "application/json",
    "Authorization": "fsq3twCI7l4mloSQPK8QK00YCDLCHJPNRsle/zUHYF59lLk="
}
#for row in df.iterrows():
  #  lat_long = row["latitude"] + "," + row["longitude"]
   # params = {
   # "query": "restaurant",
   # "radius": 1000,
   # "ll":lat_long
  #      }
response = requests.get(url, headers=headers)

pprint(response.json())
# Out:
# {'context': {'geo_bounds': {'circle': {'center': {'latitude': 45.15866370764634,
#                                                   'longitude': 10.783718973016335},
#                                        'radius': 1000}}},
#  'results': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13003,
#                               'name': 'Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#                                        'suffix': '.png'},
#                               'id': 13034,
#                               'name': 'Café'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'chains': [],
#               'distance': 25,
#               'fsq_id': '5270eabf11d283e6fe8550e9',
#               'geocodes': {'main': {'latitude': 45.158514,
#                                     'longitude': 10.78456},
#                            'roof': {'latitude': 45.158514,
#                                     'longitude': 10.78456}},
#               'link': '/v3/places/5270eabf11d283e6fe8550e9',
#               'location': {'address': 'Piazza Don Eugenio Leoni 13',
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': 'Piazza Don Eugenio Leoni 13, '
#                                                 '46100 Mantova Mantova',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Mantova'},
#               'name': 'Bar Buffet Stazione Mantova',
#               'related_places': {},
#               'timezone': 'Europe/Rome'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13134,
#                               'name': 'Comfort Food Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#                                        'suffix': '.png'},
#                               'id': 13236,
#                               'name': 'Italian Restaurant'}],
#               'chains': [],
#               'distance': 257,
#               'fsq_id': '4f245cfbe4b04f6e69201041',
#               'geocodes': {'drop_off': {'latitude': 45.156605,
#                                         'longitude': 10.785051},
#                            'main': {'latitude': 45.156465,
#                                     'longitude': 10.785125},
#                            'roof': {'latitude': 45.156465,
#                                     'longitude': 10.785125}},
#               'link': '/v3/places/4f245cfbe4b04f6e69201041',
#               'location': {'address': 'Via Carbonati 4',
#                            'address_extended': '6',
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': 'Via Carbonati 4, 46100 '
#                                                 'Mantova Lombardia',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Lombardia'},
#               'name': 'Osteria da Bice La Gallina Felice',
#               'related_places': {},
#               'timezone': 'Europe/Rome'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#                                        'suffix': '.png'},
#                               'id': 13288,
#                               'name': 'Kebab Restaurant'}],
#               'chains': [],
#               'distance': 94,
#               'fsq_id': '577e3ae3498e49f976d8a820',
#               'geocodes': {'drop_off': {'latitude': 45.158014,
#                                         'longitude': 10.782567},
#                            'main': {'latitude': 45.157916,
#                                     'longitude': 10.782667},
#                            'roof': {'latitude': 45.157916,
#                                     'longitude': 10.782667}},
#               'link': '/v3/places/577e3ae3498e49f976d8a820',
#               'location': {'address': 'Via Saverio Bettinelli 15',
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': 'Via Saverio Bettinelli 15, '
#                                                 '46100 Mantova Lombardia',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Lombardia'},
#               'name': 'Lahore Kebab',
#               'related_places': {},
#               'timezone': 'Europe/Rome'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#                                        'suffix': '.png'},
#                               'id': 13236,
#                               'name': 'Italian Restaurant'}],
#               'chains': [],
#               'distance': 126,
#               'fsq_id': '5ac0e08253159307708859aa',
#               'geocodes': {'drop_off': {'latitude': 45.159074,
#                                         'longitude': 10.785152},
#                            'main': {'latitude': 45.158954,
#                                     'longitude': 10.785214},
#                            'roof': {'latitude': 45.158954,
#                                     'longitude': 10.785214}},
#               'link': '/v3/places/5ac0e08253159307708859aa',
#               'location': {'address': 'Via Solferino e San Martino 31',
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': 'Via Solferino e San Martino '
#                                                 '31, 46100 Mantova Lombardia',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Lombardia'},
#               'name': 'Bigoleria Al Torchio',
#               'related_places': {},
#               'timezone': 'Europe/Rome'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#                                        'suffix': '.png'},
#                               'id': 13064,
#                               'name': 'Pizzeria'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#                                        'suffix': '.png'},
#                               'id': 13258,
#                               'name': 'Trattoria'}],
#               'chains': [],
#               'distance': 373,
#               'fsq_id': '4db48df14df05e5aaae24c83',
#               'geocodes': {'drop_off': {'latitude': 45.159029,
#                                         'longitude': 10.78855},
#                            'main': {'latitude': 45.159126,
#                                     'longitude': 10.788632},
#                            'roof': {'latitude': 45.159126,
#                                     'longitude': 10.788632}},
#               'link': '/v3/places/4db48df14df05e5aaae24c83',
#               'location': {'address': 'Via Marangoni 34',
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': 'Via Marangoni 34, 46100 '
#                                                 'Mantova Lombardia',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Lombardia'},
#               'name': 'Spirito Divino',
#               'related_places': {},
#               'timezone': 'Europe/Rome'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#                                        'suffix': '.png'},
#                               'id': 13034,
#                               'name': 'Café'}],
#               'chains': [],
#               'distance': 144,
#               'fsq_id': '51000343e4b055a6fd7f829c',
#               'geocodes': {'drop_off': {'latitude': 45.157454,
#                                         'longitude': 10.784743},
#                            'main': {'latitude': 45.157646,
#                                     'longitude': 10.784735},
#                            'roof': {'latitude': 45.157646,
#                                     'longitude': 10.784735}},
#               'link': '/v3/places/51000343e4b055a6fd7f829c',
#               'location': {'address': 'Via Vittorio Emanuele',
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': 'Via Vittorio Emanuele, 46100 '
#                                                 'Mantova Lombardia',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Lombardia'},
#               'name': 'Caffè 29',
#               'related_places': {},
#               'timezone': 'Europe/Rome'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13003,
#                               'name': 'Bar'}],
#               'chains': [],
#               'distance': 162,
#               'fsq_id': '5a25fc13d552c759b76d699a',
#               'geocodes': {'drop_off': {'latitude': 45.157372,
#                                         'longitude': 10.782817},
#                            'main': {'latitude': 45.157267,
#                                     'longitude': 10.782822},
#                            'roof': {'latitude': 45.157267,
#                                     'longitude': 10.782822}},
#               'link': '/v3/places/5a25fc13d552c759b76d699a',
#               'location': {'address': 'Corso Vittorio Emanuele II 144',
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': 'Corso Vittorio Emanuele II '
#                                                 '144, 46100 Mantova Lombardia',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Lombardia'},
#               'name': 'Bistro Bar Porta Pradella',
#               'related_places': {},
#               'timezone': 'Europe/Rome'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#                                        'suffix': '.png'},
#                               'id': 13064,
#                               'name': 'Pizzeria'}],
#               'chains': [],
#               'distance': 168,
#               'fsq_id': '5d62e04487398a00086a1006',
#               'geocodes': {'drop_off': {'latitude': 45.158193,
#                                         'longitude': 10.785714},
#                            'main': {'latitude': 45.158101,
#                                     'longitude': 10.785574},
#                            'roof': {'latitude': 45.158101,
#                                     'longitude': 10.785574}},
#               'link': '/v3/places/5d62e04487398a00086a1006',
#               'location': {'address': 'Via Bonomi 4',
#                            'address_extended': 'D',
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': 'Via Bonomi 4, 46100 Mantova '
#                                                 'Lombardia',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Lombardia'},
#               'name': 'Crosta',
#               'related_places': {},
#               'timezone': 'Europe/Rome'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#                                        'suffix': '.png'},
#                               'id': 13258,
#                               'name': 'Trattoria'}],
#               'chains': [],
#               'distance': 504,
#               'fsq_id': '4c488a70417b20a1af4be1a9',
#               'geocodes': {'main': {'latitude': 45.160319,
#                                     'longitude': 10.789726},
#                            'roof': {'latitude': 45.160319,
#                                     'longitude': 10.789726}},
#               'link': '/v3/places/4c488a70417b20a1af4be1a9',
#               'location': {'address': "Piazza Carlo d'Arco 1",
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': "Piazza Carlo d'Arco 1, 46100 "
#                                                 'Mantova Lombardia',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Lombardia'},
#               'name': 'Ristorante Il Cigno dei Martini',
#               'related_places': {},
#               'timezone': 'Europe/Rome'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'chains': [],
#               'distance': 536,
#               'fsq_id': '4e3d791db61cb577be7779a1',
#               'geocodes': {'main': {'latitude': 45.157239,
#                                     'longitude': 10.777163}},
#               'link': '/v3/places/4e3d791db61cb577be7779a1',
#               'location': {'address': "Lungolago dell'Arlecchino 6",
#                            'admin_region': 'Lombardia',
#                            'country': 'IT',
#                            'cross_street': '',
#                            'formatted_address': "Lungolago dell'Arlecchino 6, "
#                                                 '46100 Mantova Lombardia',
#                            'locality': 'Mantova',
#                            'postcode': '46100',
#                            'region': 'Lombardia'},
#               'name': 'Rifugio',
#               'related_places': {},
#               'timezone': 'Europe/Rome'}]}

# %%
df_json = response.json()
df_json = df_json['results']
df2 = pd.json_normalize(df_json)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df2
# Out:
#                      fsq_id  \
# 0  5270eabf11d283e6fe8550e9
# 1  4f245cfbe4b04f6e69201041
# 2  577e3ae3498e49f976d8a820
# 3  5ac0e08253159307708859aa
# 4  4db48df14df05e5aaae24c83
# 5  51000343e4b055a6fd7f829c
# 6  5a25fc13d552c759b76d699a
# 7  5d62e04487398a00086a1006
# 8  4c488a70417b20a1af4be1a9
# 9  4e3d791db61cb577be7779a1
#
#                                           categories chains  distance  \
# 0  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []        25
# 1  [{'id': 13134, 'name': 'Comfort Food Restauran...     []       257
# 2  [{'id': 13288, 'name': 'Kebab Restaurant', 'ic...     []        94
# 3  [{'id': 13236, 'name': 'Italian Restaurant', '...     []       126
# 4  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...     []       373
# 5  [{'id': 13034, 'name': 'Café', 'icon': {'prefi...     []       144
# 6  [{'id': 13065, 'name': 'Restaurant', 'icon': {...     []       162
# 7  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...     []       168
# 8  [{'id': 13258, 'name': 'Trattoria', 'icon': {'...     []       504
# 9  [{'id': 13065, 'name': 'Restaurant', 'icon': {...     []       536
#
#                                   link                               name  \
# 0  /v3/places/5270eabf11d283e6fe8550e9        Bar Buffet Stazione Mantova
# 1  /v3/places/4f245cfbe4b04f6e69201041  Osteria da Bice La Gallina Felice
# 2  /v3/places/577e3ae3498e49f976d8a820                       Lahore Kebab
# 3  /v3/places/5ac0e08253159307708859aa               Bigoleria Al Torchio
# 4  /v3/places/4db48df14df05e5aaae24c83                     Spirito Divino
# 5  /v3/places/51000343e4b055a6fd7f829c                           Caffè 29
# 6  /v3/places/5a25fc13d552c759b76d699a          Bistro Bar Porta Pradella
# 7  /v3/places/5d62e04487398a00086a1006                             Crosta
# 8  /v3/places/4c488a70417b20a1af4be1a9    Ristorante Il Cigno dei Martini
# 9  /v3/places/4e3d791db61cb577be7779a1                            Rifugio
#
#       timezone  geocodes.main.latitude  geocodes.main.longitude  \
# 0  Europe/Rome               45.158514                10.784560
# 1  Europe/Rome               45.156465                10.785125
# 2  Europe/Rome               45.157916                10.782667
# 3  Europe/Rome               45.158954                10.785214
# 4  Europe/Rome               45.159126                10.788632
# 5  Europe/Rome               45.157646                10.784735
# 6  Europe/Rome               45.157267                10.782822
# 7  Europe/Rome               45.158101                10.785574
# 8  Europe/Rome               45.160319                10.789726
# 9  Europe/Rome               45.157239                10.777163
#
#    geocodes.roof.latitude  geocodes.roof.longitude  \
# 0               45.158514                10.784560
# 1               45.156465                10.785125
# 2               45.157916                10.782667
# 3               45.158954                10.785214
# 4               45.159126                10.788632
# 5               45.157646                10.784735
# 6               45.157267                10.782822
# 7               45.158101                10.785574
# 8               45.160319                10.789726
# 9                     NaN                      NaN
#
#                  location.address location.admin_region location.country  \
# 0     Piazza Don Eugenio Leoni 13             Lombardia               IT
# 1                 Via Carbonati 4             Lombardia               IT
# 2       Via Saverio Bettinelli 15             Lombardia               IT
# 3  Via Solferino e San Martino 31             Lombardia               IT
# 4                Via Marangoni 34             Lombardia               IT
# 5           Via Vittorio Emanuele             Lombardia               IT
# 6  Corso Vittorio Emanuele II 144             Lombardia               IT
# 7                    Via Bonomi 4             Lombardia               IT
# 8           Piazza Carlo d'Arco 1             Lombardia               IT
# 9     Lungolago dell'Arlecchino 6             Lombardia               IT
#
#   location.cross_street                         location.formatted_address  \
# 0                        Piazza Don Eugenio Leoni 13, 46100 Mantova Man...
# 1                                 Via Carbonati 4, 46100 Mantova Lombardia
# 2                        Via Saverio Bettinelli 15, 46100 Mantova Lomba...
# 3                        Via Solferino e San Martino 31, 46100 Mantova ...
# 4                                Via Marangoni 34, 46100 Mantova Lombardia
# 5                           Via Vittorio Emanuele, 46100 Mantova Lombardia
# 6                        Corso Vittorio Emanuele II 144, 46100 Mantova ...
# 7                                    Via Bonomi 4, 46100 Mantova Lombardia
# 8                           Piazza Carlo d'Arco 1, 46100 Mantova Lombardia
# 9                        Lungolago dell'Arlecchino 6, 46100 Mantova Lom...
#
#   location.locality location.postcode location.region  \
# 0           Mantova             46100         Mantova
# 1           Mantova             46100       Lombardia
# 2           Mantova             46100       Lombardia
# 3           Mantova             46100       Lombardia
# 4           Mantova             46100       Lombardia
# 5           Mantova             46100       Lombardia
# 6           Mantova             46100       Lombardia
# 7           Mantova             46100       Lombardia
# 8           Mantova             46100       Lombardia
# 9           Mantova             46100       Lombardia
#
#    geocodes.drop_off.latitude  geocodes.drop_off.longitude  \
# 0                         NaN                          NaN
# 1                   45.156605                    10.785051
# 2                   45.158014                    10.782567
# 3                   45.159074                    10.785152
# 4                   45.159029                    10.788550
# 5                   45.157454                    10.784743
# 6                   45.157372                    10.782817
# 7                   45.158193                    10.785714
# 8                         NaN                          NaN
# 9                         NaN                          NaN
#
#   location.address_extended
# 0                       NaN
# 1                         6
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                         D
# 8                       NaN
# 9                       NaN

# %%
df2.rename(columns={'geocodes.main.latitude': 'latitude', 'geocodes.main.longitude': 'longitude'}, inplace=True)
df2
# Out:
#                      fsq_id  \
# 0  5270eabf11d283e6fe8550e9
# 1  4f245cfbe4b04f6e69201041
# 2  577e3ae3498e49f976d8a820
# 3  5ac0e08253159307708859aa
# 4  4db48df14df05e5aaae24c83
# 5  51000343e4b055a6fd7f829c
# 6  5a25fc13d552c759b76d699a
# 7  5d62e04487398a00086a1006
# 8  4c488a70417b20a1af4be1a9
# 9  4e3d791db61cb577be7779a1
#
#                                           categories chains  distance  \
# 0  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []        25
# 1  [{'id': 13134, 'name': 'Comfort Food Restauran...     []       257
# 2  [{'id': 13288, 'name': 'Kebab Restaurant', 'ic...     []        94
# 3  [{'id': 13236, 'name': 'Italian Restaurant', '...     []       126
# 4  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...     []       373
# 5  [{'id': 13034, 'name': 'Café', 'icon': {'prefi...     []       144
# 6  [{'id': 13065, 'name': 'Restaurant', 'icon': {...     []       162
# 7  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...     []       168
# 8  [{'id': 13258, 'name': 'Trattoria', 'icon': {'...     []       504
# 9  [{'id': 13065, 'name': 'Restaurant', 'icon': {...     []       536
#
#                                   link                               name  \
# 0  /v3/places/5270eabf11d283e6fe8550e9        Bar Buffet Stazione Mantova
# 1  /v3/places/4f245cfbe4b04f6e69201041  Osteria da Bice La Gallina Felice
# 2  /v3/places/577e3ae3498e49f976d8a820                       Lahore Kebab
# 3  /v3/places/5ac0e08253159307708859aa               Bigoleria Al Torchio
# 4  /v3/places/4db48df14df05e5aaae24c83                     Spirito Divino
# 5  /v3/places/51000343e4b055a6fd7f829c                           Caffè 29
# 6  /v3/places/5a25fc13d552c759b76d699a          Bistro Bar Porta Pradella
# 7  /v3/places/5d62e04487398a00086a1006                             Crosta
# 8  /v3/places/4c488a70417b20a1af4be1a9    Ristorante Il Cigno dei Martini
# 9  /v3/places/4e3d791db61cb577be7779a1                            Rifugio
#
#       timezone   latitude  longitude  geocodes.roof.latitude  \
# 0  Europe/Rome  45.158514  10.784560               45.158514
# 1  Europe/Rome  45.156465  10.785125               45.156465
# 2  Europe/Rome  45.157916  10.782667               45.157916
# 3  Europe/Rome  45.158954  10.785214               45.158954
# 4  Europe/Rome  45.159126  10.788632               45.159126
# 5  Europe/Rome  45.157646  10.784735               45.157646
# 6  Europe/Rome  45.157267  10.782822               45.157267
# 7  Europe/Rome  45.158101  10.785574               45.158101
# 8  Europe/Rome  45.160319  10.789726               45.160319
# 9  Europe/Rome  45.157239  10.777163                     NaN
#
#    geocodes.roof.longitude                location.address  \
# 0                10.784560     Piazza Don Eugenio Leoni 13
# 1                10.785125                 Via Carbonati 4
# 2                10.782667       Via Saverio Bettinelli 15
# 3                10.785214  Via Solferino e San Martino 31
# 4                10.788632                Via Marangoni 34
# 5                10.784735           Via Vittorio Emanuele
# 6                10.782822  Corso Vittorio Emanuele II 144
# 7                10.785574                    Via Bonomi 4
# 8                10.789726           Piazza Carlo d'Arco 1
# 9                      NaN     Lungolago dell'Arlecchino 6
#
#   location.admin_region location.country location.cross_street  \
# 0             Lombardia               IT
# 1             Lombardia               IT
# 2             Lombardia               IT
# 3             Lombardia               IT
# 4             Lombardia               IT
# 5             Lombardia               IT
# 6             Lombardia               IT
# 7             Lombardia               IT
# 8             Lombardia               IT
# 9             Lombardia               IT
#
#                           location.formatted_address location.locality  \
# 0  Piazza Don Eugenio Leoni 13, 46100 Mantova Man...           Mantova
# 1           Via Carbonati 4, 46100 Mantova Lombardia           Mantova
# 2  Via Saverio Bettinelli 15, 46100 Mantova Lomba...           Mantova
# 3  Via Solferino e San Martino 31, 46100 Mantova ...           Mantova
# 4          Via Marangoni 34, 46100 Mantova Lombardia           Mantova
# 5     Via Vittorio Emanuele, 46100 Mantova Lombardia           Mantova
# 6  Corso Vittorio Emanuele II 144, 46100 Mantova ...           Mantova
# 7              Via Bonomi 4, 46100 Mantova Lombardia           Mantova
# 8     Piazza Carlo d'Arco 1, 46100 Mantova Lombardia           Mantova
# 9  Lungolago dell'Arlecchino 6, 46100 Mantova Lom...           Mantova
#
#   location.postcode location.region  geocodes.drop_off.latitude  \
# 0             46100         Mantova                         NaN
# 1             46100       Lombardia                   45.156605
# 2             46100       Lombardia                   45.158014
# 3             46100       Lombardia                   45.159074
# 4             46100       Lombardia                   45.159029
# 5             46100       Lombardia                   45.157454
# 6             46100       Lombardia                   45.157372
# 7             46100       Lombardia                   45.158193
# 8             46100       Lombardia                         NaN
# 9             46100       Lombardia                         NaN
#
#    geocodes.drop_off.longitude location.address_extended
# 0                          NaN                       NaN
# 1                    10.785051                         6
# 2                    10.782567                       NaN
# 3                    10.785152                       NaN
# 4                    10.788550                       NaN
# 5                    10.784743                       NaN
# 6                    10.782817                       NaN
# 7                    10.785714                         D
# 8                          NaN                       NaN
# 9                          NaN                       NaN

# %%
df_combined = pd.concat([df1, df2])
df_combined
# Out:
#    empty_slots  free_bikes                                id   latitude  \
# 0          0.0         0.0  9be01b509184baee960fcffa4f1425d3  45.158664
# 1          0.0         0.0  2eb2a00e80e5d6fee19b932294a08927  45.147505
# 2          0.0         0.0  f2703a28d2f9f3a0e4078867966d4536  45.162056
# 3          0.0         0.0  2fd7039e15452a7a09b5ddca816a6375  45.157558
# 4          8.0         0.0  a97d2eb0b413d91a627e8e661356471b  45.153567
# 5          0.0         0.0  388ea79ccc1898766848156901c20c1b  45.157522
# 6          0.0         0.0  5cd1352f5e895893f577ceba80c0bd41  45.162355
# 7          0.0         0.0  43b4d9fcbb4e5b825350b3e43e9941af  45.150072
# 0          NaN         NaN                               NaN  45.158514
# 1          NaN         NaN                               NaN  45.156465
# 2          NaN         NaN                               NaN  45.157916
# 3          NaN         NaN                               NaN  45.158954
# 4          NaN         NaN                               NaN  45.159126
# 5          NaN         NaN                               NaN  45.157646
# 6          NaN         NaN                               NaN  45.157267
# 7          NaN         NaN                               NaN  45.158101
# 8          NaN         NaN                               NaN  45.160319
# 9          NaN         NaN                               NaN  45.157239
#
#    longitude                               name                    timestamp  \
# 0  10.783719                    Stazione FF.SS.  2023-08-02T22:51:07.196000Z
# 1  10.795176                       Porta Cerese  2023-08-02T22:51:07.197000Z
# 2  10.811605                        Campo Canoa  2023-08-02T22:51:07.197000Z
# 3  10.794851                        Castiglioni  2023-08-02T22:51:07.197000Z
# 4  10.797891                          Anconetta  2023-08-02T22:51:07.197000Z
# 5  10.790304                          Umberto I  2023-08-02T22:51:07.197000Z
# 6  10.798728                Castello S. Giorgio  2023-08-02T22:51:07.197000Z
# 7  10.786767                         Palazzo Te  2023-08-02T22:51:07.197000Z
# 0  10.784560        Bar Buffet Stazione Mantova                          NaN
# 1  10.785125  Osteria da Bice La Gallina Felice                          NaN
# 2  10.782667                       Lahore Kebab                          NaN
# 3  10.785214               Bigoleria Al Torchio                          NaN
# 4  10.788632                     Spirito Divino                          NaN
# 5  10.784735                           Caffè 29                          NaN
# 6  10.782822          Bistro Bar Porta Pradella                          NaN
# 7  10.785574                             Crosta                          NaN
# 8  10.789726    Ristorante Il Cigno dei Martini                          NaN
# 9  10.777163                            Rifugio                          NaN
#
#    extra.number  extra.reviews  extra.score extra.status extra.uid  \
# 0           1.0            7.0          3.7      offline      1310
# 1           2.0            1.0          1.0      offline      1311
# 2           3.0            1.0          1.0      offline      1312
# 3           4.0            1.0          1.0      offline      1313
# 4           5.0            1.0          1.0      offline      1314
# 5           6.0            2.0          2.9      offline      1315
# 6           7.0            3.0          2.0      offline      1316
# 7           8.0            1.0          1.0      offline      1499
# 0           NaN            NaN          NaN          NaN       NaN
# 1           NaN            NaN          NaN          NaN       NaN
# 2           NaN            NaN          NaN          NaN       NaN
# 3           NaN            NaN          NaN          NaN       NaN
# 4           NaN            NaN          NaN          NaN       NaN
# 5           NaN            NaN          NaN          NaN       NaN
# 6           NaN            NaN          NaN          NaN       NaN
# 7           NaN            NaN          NaN          NaN       NaN
# 8           NaN            NaN          NaN          NaN       NaN
# 9           NaN            NaN          NaN          NaN       NaN
#
#                      fsq_id  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 0  5270eabf11d283e6fe8550e9
# 1  4f245cfbe4b04f6e69201041
# 2  577e3ae3498e49f976d8a820
# 3  5ac0e08253159307708859aa
# 4  4db48df14df05e5aaae24c83
# 5  51000343e4b055a6fd7f829c
# 6  5a25fc13d552c759b76d699a
# 7  5d62e04487398a00086a1006
# 8  4c488a70417b20a1af4be1a9
# 9  4e3d791db61cb577be7779a1
#
#                                           categories chains  distance  \
# 0                                                NaN    NaN       NaN
# 1                                                NaN    NaN       NaN
# 2                                                NaN    NaN       NaN
# 3                                                NaN    NaN       NaN
# 4                                                NaN    NaN       NaN
# 5                                                NaN    NaN       NaN
# 6                                                NaN    NaN       NaN
# 7                                                NaN    NaN       NaN
# 0  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      25.0
# 1  [{'id': 13134, 'name': 'Comfort Food Restauran...     []     257.0
# 2  [{'id': 13288, 'name': 'Kebab Restaurant', 'ic...     []      94.0
# 3  [{'id': 13236, 'name': 'Italian Restaurant', '...     []     126.0
# 4  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...     []     373.0
# 5  [{'id': 13034, 'name': 'Café', 'icon': {'prefi...     []     144.0
# 6  [{'id': 13065, 'name': 'Restaurant', 'icon': {...     []     162.0
# 7  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...     []     168.0
# 8  [{'id': 13258, 'name': 'Trattoria', 'icon': {'...     []     504.0
# 9  [{'id': 13065, 'name': 'Restaurant', 'icon': {...     []     536.0
#
#                                   link     timezone  geocodes.roof.latitude  \
# 0                                  NaN          NaN                     NaN
# 1                                  NaN          NaN                     NaN
# 2                                  NaN          NaN                     NaN
# 3                                  NaN          NaN                     NaN
# 4                                  NaN          NaN                     NaN
# 5                                  NaN          NaN                     NaN
# 6                                  NaN          NaN                     NaN
# 7                                  NaN          NaN                     NaN
# 0  /v3/places/5270eabf11d283e6fe8550e9  Europe/Rome               45.158514
# 1  /v3/places/4f245cfbe4b04f6e69201041  Europe/Rome               45.156465
# 2  /v3/places/577e3ae3498e49f976d8a820  Europe/Rome               45.157916
# 3  /v3/places/5ac0e08253159307708859aa  Europe/Rome               45.158954
# 4  /v3/places/4db48df14df05e5aaae24c83  Europe/Rome               45.159126
# 5  /v3/places/51000343e4b055a6fd7f829c  Europe/Rome               45.157646
# 6  /v3/places/5a25fc13d552c759b76d699a  Europe/Rome               45.157267
# 7  /v3/places/5d62e04487398a00086a1006  Europe/Rome               45.158101
# 8  /v3/places/4c488a70417b20a1af4be1a9  Europe/Rome               45.160319
# 9  /v3/places/4e3d791db61cb577be7779a1  Europe/Rome                     NaN
#
#    geocodes.roof.longitude                location.address  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
# 5                      NaN                             NaN
# 6                      NaN                             NaN
# 7                      NaN                             NaN
# 0                10.784560     Piazza Don Eugenio Leoni 13
# 1                10.785125                 Via Carbonati 4
# 2                10.782667       Via Saverio Bettinelli 15
# 3                10.785214  Via Solferino e San Martino 31
# 4                10.788632                Via Marangoni 34
# 5                10.784735           Via Vittorio Emanuele
# 6                10.782822  Corso Vittorio Emanuele II 144
# 7                10.785574                    Via Bonomi 4
# 8                10.789726           Piazza Carlo d'Arco 1
# 9                      NaN     Lungolago dell'Arlecchino 6
#
#   location.admin_region location.country location.cross_street  \
# 0                   NaN              NaN                   NaN
# 1                   NaN              NaN                   NaN
# 2                   NaN              NaN                   NaN
# 3                   NaN              NaN                   NaN
# 4                   NaN              NaN                   NaN
# 5                   NaN              NaN                   NaN
# 6                   NaN              NaN                   NaN
# 7                   NaN              NaN                   NaN
# 0             Lombardia               IT
# 1             Lombardia               IT
# 2             Lombardia               IT
# 3             Lombardia               IT
# 4             Lombardia               IT
# 5             Lombardia               IT
# 6             Lombardia               IT
# 7             Lombardia               IT
# 8             Lombardia               IT
# 9             Lombardia               IT
#
#                           location.formatted_address location.locality  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5                                                NaN               NaN
# 6                                                NaN               NaN
# 7                                                NaN               NaN
# 0  Piazza Don Eugenio Leoni 13, 46100 Mantova Man...           Mantova
# 1           Via Carbonati 4, 46100 Mantova Lombardia           Mantova
# 2  Via Saverio Bettinelli 15, 46100 Mantova Lomba...           Mantova
# 3  Via Solferino e San Martino 31, 46100 Mantova ...           Mantova
# 4          Via Marangoni 34, 46100 Mantova Lombardia           Mantova
# 5     Via Vittorio Emanuele, 46100 Mantova Lombardia           Mantova
# 6  Corso Vittorio Emanuele II 144, 46100 Mantova ...           Mantova
# 7              Via Bonomi 4, 46100 Mantova Lombardia           Mantova
# 8     Piazza Carlo d'Arco 1, 46100 Mantova Lombardia           Mantova
# 9  Lungolago dell'Arlecchino 6, 46100 Mantova Lom...           Mantova
#
#   location.postcode location.region  geocodes.drop_off.latitude  \
# 0               NaN             NaN                         NaN
# 1               NaN             NaN                         NaN
# 2               NaN             NaN                         NaN
# 3               NaN             NaN                         NaN
# 4               NaN             NaN                         NaN
# 5               NaN             NaN                         NaN
# 6               NaN             NaN                         NaN
# 7               NaN             NaN                         NaN
# 0             46100         Mantova                         NaN
# 1             46100       Lombardia                   45.156605
# 2             46100       Lombardia                   45.158014
# 3             46100       Lombardia                   45.159074
# 4             46100       Lombardia                   45.159029
# 5             46100       Lombardia                   45.157454
# 6             46100       Lombardia                   45.157372
# 7             46100       Lombardia                   45.158193
# 8             46100       Lombardia                         NaN
# 9             46100       Lombardia                         NaN
#
#    geocodes.drop_off.longitude location.address_extended
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# 5                          NaN                       NaN
# 6                          NaN                       NaN
# 7                          NaN                       NaN
# 0                          NaN                       NaN
# 1                    10.785051                         6
# 2                    10.782567                       NaN
# 3                    10.785152                       NaN
# 4                    10.788550                       NaN
# 5                    10.784743                       NaN
# 6                    10.782817                       NaN
# 7                    10.785714                         D
# 8                          NaN                       NaN
# 9                          NaN                       NaN

# %%
merged_df = pd.merge(df1, df2, on='latitude', how='outer')
print(merged_df)
# Out:
#     empty_slots  free_bikes                                id   latitude  \
# 0           0.0         0.0  9be01b509184baee960fcffa4f1425d3  45.158664
# 1           0.0         0.0  2eb2a00e80e5d6fee19b932294a08927  45.147505
# 2           0.0         0.0  f2703a28d2f9f3a0e4078867966d4536  45.162056
# 3           0.0         0.0  2fd7039e15452a7a09b5ddca816a6375  45.157558
# 4           8.0         0.0  a97d2eb0b413d91a627e8e661356471b  45.153567
# 5           0.0         0.0  388ea79ccc1898766848156901c20c1b  45.157522
# 6           0.0         0.0  5cd1352f5e895893f577ceba80c0bd41  45.162355
# 7           0.0         0.0  43b4d9fcbb4e5b825350b3e43e9941af  45.150072
# 8           NaN         NaN                               NaN  45.158514
# 9           NaN         NaN                               NaN  45.156465
# 10          NaN         NaN                               NaN  45.157916
# 11          NaN         NaN                               NaN  45.158954
# 12          NaN         NaN                               NaN  45.159126
# 13          NaN         NaN                               NaN  45.157646
# 14          NaN         NaN                               NaN  45.157267
# 15          NaN         NaN                               NaN  45.158101
# 16          NaN         NaN                               NaN  45.160319
# 17          NaN         NaN                               NaN  45.157239
#
#     longitude_x               name_x                    timestamp  \
# 0     10.783719      Stazione FF.SS.  2023-08-02T22:51:07.196000Z
# 1     10.795176         Porta Cerese  2023-08-02T22:51:07.197000Z
# 2     10.811605          Campo Canoa  2023-08-02T22:51:07.197000Z
# 3     10.794851          Castiglioni  2023-08-02T22:51:07.197000Z
# 4     10.797891            Anconetta  2023-08-02T22:51:07.197000Z
# 5     10.790304            Umberto I  2023-08-02T22:51:07.197000Z
# 6     10.798728  Castello S. Giorgio  2023-08-02T22:51:07.197000Z
# 7     10.786767           Palazzo Te  2023-08-02T22:51:07.197000Z
# 8           NaN                  NaN                          NaN
# 9           NaN                  NaN                          NaN
# 10          NaN                  NaN                          NaN
# 11          NaN                  NaN                          NaN
# 12          NaN                  NaN                          NaN
# 13          NaN                  NaN                          NaN
# 14          NaN                  NaN                          NaN
# 15          NaN                  NaN                          NaN
# 16          NaN                  NaN                          NaN
# 17          NaN                  NaN                          NaN
#
#     extra.number  extra.reviews  extra.score extra.status extra.uid  \
# 0            1.0            7.0          3.7      offline      1310
# 1            2.0            1.0          1.0      offline      1311
# 2            3.0            1.0          1.0      offline      1312
# 3            4.0            1.0          1.0      offline      1313
# 4            5.0            1.0          1.0      offline      1314
# 5            6.0            2.0          2.9      offline      1315
# 6            7.0            3.0          2.0      offline      1316
# 7            8.0            1.0          1.0      offline      1499
# 8            NaN            NaN          NaN          NaN       NaN
# 9            NaN            NaN          NaN          NaN       NaN
# 10           NaN            NaN          NaN          NaN       NaN
# 11           NaN            NaN          NaN          NaN       NaN
# 12           NaN            NaN          NaN          NaN       NaN
# 13           NaN            NaN          NaN          NaN       NaN
# 14           NaN            NaN          NaN          NaN       NaN
# 15           NaN            NaN          NaN          NaN       NaN
# 16           NaN            NaN          NaN          NaN       NaN
# 17           NaN            NaN          NaN          NaN       NaN
#
#                       fsq_id  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8   5270eabf11d283e6fe8550e9
# 9   4f245cfbe4b04f6e69201041
# 10  577e3ae3498e49f976d8a820
# 11  5ac0e08253159307708859aa
# 12  4db48df14df05e5aaae24c83
# 13  51000343e4b055a6fd7f829c
# 14  5a25fc13d552c759b76d699a
# 15  5d62e04487398a00086a1006
# 16  4c488a70417b20a1af4be1a9
# 17  4e3d791db61cb577be7779a1
#
#                                            categories chains  distance  \
# 0                                                 NaN    NaN       NaN
# 1                                                 NaN    NaN       NaN
# 2                                                 NaN    NaN       NaN
# 3                                                 NaN    NaN       NaN
# 4                                                 NaN    NaN       NaN
# 5                                                 NaN    NaN       NaN
# 6                                                 NaN    NaN       NaN
# 7                                                 NaN    NaN       NaN
# 8   [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []      25.0
# 9   [{'id': 13134, 'name': 'Comfort Food Restauran...     []     257.0
# 10  [{'id': 13288, 'name': 'Kebab Restaurant', 'ic...     []      94.0
# 11  [{'id': 13236, 'name': 'Italian Restaurant', '...     []     126.0
# 12  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...     []     373.0
# 13  [{'id': 13034, 'name': 'Café', 'icon': {'prefi...     []     144.0
# 14  [{'id': 13065, 'name': 'Restaurant', 'icon': {...     []     162.0
# 15  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...     []     168.0
# 16  [{'id': 13258, 'name': 'Trattoria', 'icon': {'...     []     504.0
# 17  [{'id': 13065, 'name': 'Restaurant', 'icon': {...     []     536.0
#
#                                    link                             name_y  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# 5                                   NaN                                NaN
# 6                                   NaN                                NaN
# 7                                   NaN                                NaN
# 8   /v3/places/5270eabf11d283e6fe8550e9        Bar Buffet Stazione Mantova
# 9   /v3/places/4f245cfbe4b04f6e69201041  Osteria da Bice La Gallina Felice
# 10  /v3/places/577e3ae3498e49f976d8a820                       Lahore Kebab
# 11  /v3/places/5ac0e08253159307708859aa               Bigoleria Al Torchio
# 12  /v3/places/4db48df14df05e5aaae24c83                     Spirito Divino
# 13  /v3/places/51000343e4b055a6fd7f829c                           Caffè 29
# 14  /v3/places/5a25fc13d552c759b76d699a          Bistro Bar Porta Pradella
# 15  /v3/places/5d62e04487398a00086a1006                             Crosta
# 16  /v3/places/4c488a70417b20a1af4be1a9    Ristorante Il Cigno dei Martini
# 17  /v3/places/4e3d791db61cb577be7779a1                            Rifugio
#
#        timezone  longitude_y  geocodes.roof.latitude  geocodes.roof.longitude  \
# 0           NaN          NaN                     NaN                      NaN
# 1           NaN          NaN                     NaN                      NaN
# 2           NaN          NaN                     NaN                      NaN
# 3           NaN          NaN                     NaN                      NaN
# 4           NaN          NaN                     NaN                      NaN
# 5           NaN          NaN                     NaN                      NaN
# 6           NaN          NaN                     NaN                      NaN
# 7           NaN          NaN                     NaN                      NaN
# 8   Europe/Rome    10.784560               45.158514                10.784560
# 9   Europe/Rome    10.785125               45.156465                10.785125
# 10  Europe/Rome    10.782667               45.157916                10.782667
# 11  Europe/Rome    10.785214               45.158954                10.785214
# 12  Europe/Rome    10.788632               45.159126                10.788632
# 13  Europe/Rome    10.784735               45.157646                10.784735
# 14  Europe/Rome    10.782822               45.157267                10.782822
# 15  Europe/Rome    10.785574               45.158101                10.785574
# 16  Europe/Rome    10.789726               45.160319                10.789726
# 17  Europe/Rome    10.777163                     NaN                      NaN
#
#                   location.address location.admin_region location.country  \
# 0                              NaN                   NaN              NaN
# 1                              NaN                   NaN              NaN
# 2                              NaN                   NaN              NaN
# 3                              NaN                   NaN              NaN
# 4                              NaN                   NaN              NaN
# 5                              NaN                   NaN              NaN
# 6                              NaN                   NaN              NaN
# 7                              NaN                   NaN              NaN
# 8      Piazza Don Eugenio Leoni 13             Lombardia               IT
# 9                  Via Carbonati 4             Lombardia               IT
# 10       Via Saverio Bettinelli 15             Lombardia               IT
# 11  Via Solferino e San Martino 31             Lombardia               IT
# 12                Via Marangoni 34             Lombardia               IT
# 13           Via Vittorio Emanuele             Lombardia               IT
# 14  Corso Vittorio Emanuele II 144             Lombardia               IT
# 15                    Via Bonomi 4             Lombardia               IT
# 16           Piazza Carlo d'Arco 1             Lombardia               IT
# 17     Lungolago dell'Arlecchino 6             Lombardia               IT
#
#    location.cross_street                         location.formatted_address  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# 5                    NaN                                                NaN
# 6                    NaN                                                NaN
# 7                    NaN                                                NaN
# 8                         Piazza Don Eugenio Leoni 13, 46100 Mantova Man...
# 9                                  Via Carbonati 4, 46100 Mantova Lombardia
# 10                        Via Saverio Bettinelli 15, 46100 Mantova Lomba...
# 11                        Via Solferino e San Martino 31, 46100 Mantova ...
# 12                                Via Marangoni 34, 46100 Mantova Lombardia
# 13                           Via Vittorio Emanuele, 46100 Mantova Lombardia
# 14                        Corso Vittorio Emanuele II 144, 46100 Mantova ...
# 15                                    Via Bonomi 4, 46100 Mantova Lombardia
# 16                           Piazza Carlo d'Arco 1, 46100 Mantova Lombardia
# 17                        Lungolago dell'Arlecchino 6, 46100 Mantova Lom...
#
#    location.locality location.postcode location.region  \
# 0                NaN               NaN             NaN
# 1                NaN               NaN             NaN
# 2                NaN               NaN             NaN
# 3                NaN               NaN             NaN
# 4                NaN               NaN             NaN
# 5                NaN               NaN             NaN
# 6                NaN               NaN             NaN
# 7                NaN               NaN             NaN
# 8            Mantova             46100         Mantova
# 9            Mantova             46100       Lombardia
# 10           Mantova             46100       Lombardia
# 11           Mantova             46100       Lombardia
# 12           Mantova             46100       Lombardia
# 13           Mantova             46100       Lombardia
# 14           Mantova             46100       Lombardia
# 15           Mantova             46100       Lombardia
# 16           Mantova             46100       Lombardia
# 17           Mantova             46100       Lombardia
#
#     geocodes.drop_off.latitude  geocodes.drop_off.longitude  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                          NaN                          NaN
# 6                          NaN                          NaN
# 7                          NaN                          NaN
# 8                          NaN                          NaN
# 9                    45.156605                    10.785051
# 10                   45.158014                    10.782567
# 11                   45.159074                    10.785152
# 12                   45.159029                    10.788550
# 13                   45.157454                    10.784743
# 14                   45.157372                    10.782817
# 15                   45.158193                    10.785714
# 16                         NaN                          NaN
# 17                         NaN                          NaN
#
#    location.address_extended
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                          6
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                         D
# 16                       NaN
# 17                       NaN

# %%
#merged_df = pd.merge(df1, df2, on='latitude', how='inner')
#print(merged_df)
# Out:
# Empty DataFrame
# Columns: [empty_slots, free_bikes, id, latitude, longitude_x, name_x, timestamp, extra.number, extra.reviews, extra.score, extra.status, extra.uid, fsq_id, categories, chains, distance, link, name_y, timezone, longitude_y, geocodes.roof.latitude, geocodes.roof.longitude, location.address, location.admin_region, location.country, location.cross_street, location.formatted_address, location.locality, location.postcode, location.region, geocodes.drop_off.latitude, geocodes.drop_off.longitude, location.address_extended]
# Index: []

# %%
#merged_df = pd.merge(df1, df2, on='latitude', how='left')
#print(merged_df)
# Out:
#    empty_slots  free_bikes                                id   latitude  \
# 0            0           0  9be01b509184baee960fcffa4f1425d3  45.158664
# 1            0           0  2eb2a00e80e5d6fee19b932294a08927  45.147505
# 2            0           0  f2703a28d2f9f3a0e4078867966d4536  45.162056
# 3            0           0  2fd7039e15452a7a09b5ddca816a6375  45.157558
# 4            8           0  a97d2eb0b413d91a627e8e661356471b  45.153567
# 5            0           0  388ea79ccc1898766848156901c20c1b  45.157522
# 6            0           0  5cd1352f5e895893f577ceba80c0bd41  45.162355
# 7            0           0  43b4d9fcbb4e5b825350b3e43e9941af  45.150072
#
#    longitude_x               name_x                    timestamp  \
# 0    10.783719      Stazione FF.SS.  2023-08-02T22:51:07.196000Z
# 1    10.795176         Porta Cerese  2023-08-02T22:51:07.197000Z
# 2    10.811605          Campo Canoa  2023-08-02T22:51:07.197000Z
# 3    10.794851          Castiglioni  2023-08-02T22:51:07.197000Z
# 4    10.797891            Anconetta  2023-08-02T22:51:07.197000Z
# 5    10.790304            Umberto I  2023-08-02T22:51:07.197000Z
# 6    10.798728  Castello S. Giorgio  2023-08-02T22:51:07.197000Z
# 7    10.786767           Palazzo Te  2023-08-02T22:51:07.197000Z
#
#    extra.number  extra.reviews  extra.score extra.status extra.uid fsq_id  \
# 0             1              7          3.7      offline      1310    NaN
# 1             2              1          1.0      offline      1311    NaN
# 2             3              1          1.0      offline      1312    NaN
# 3             4              1          1.0      offline      1313    NaN
# 4             5              1          1.0      offline      1314    NaN
# 5             6              2          2.9      offline      1315    NaN
# 6             7              3          2.0      offline      1316    NaN
# 7             8              1          1.0      offline      1499    NaN
#
#   categories chains  distance link name_y timezone  longitude_y  \
# 0        NaN    NaN       NaN  NaN    NaN      NaN          NaN
# 1        NaN    NaN       NaN  NaN    NaN      NaN          NaN
# 2        NaN    NaN       NaN  NaN    NaN      NaN          NaN
# 3        NaN    NaN       NaN  NaN    NaN      NaN          NaN
# 4        NaN    NaN       NaN  NaN    NaN      NaN          NaN
# 5        NaN    NaN       NaN  NaN    NaN      NaN          NaN
# 6        NaN    NaN       NaN  NaN    NaN      NaN          NaN
# 7        NaN    NaN       NaN  NaN    NaN      NaN          NaN
#
#    geocodes.roof.latitude  geocodes.roof.longitude location.address  \
# 0                     NaN                      NaN              NaN
# 1                     NaN                      NaN              NaN
# 2                     NaN                      NaN              NaN
# 3                     NaN                      NaN              NaN
# 4                     NaN                      NaN              NaN
# 5                     NaN                      NaN              NaN
# 6                     NaN                      NaN              NaN
# 7                     NaN                      NaN              NaN
#
#   location.admin_region location.country location.cross_street  \
# 0                   NaN              NaN                   NaN
# 1                   NaN              NaN                   NaN
# 2                   NaN              NaN                   NaN
# 3                   NaN              NaN                   NaN
# 4                   NaN              NaN                   NaN
# 5                   NaN              NaN                   NaN
# 6                   NaN              NaN                   NaN
# 7                   NaN              NaN                   NaN
#
#   location.formatted_address location.locality location.postcode  \
# 0                        NaN               NaN               NaN
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               NaN
# 3                        NaN               NaN               NaN
# 4                        NaN               NaN               NaN
# 5                        NaN               NaN               NaN
# 6                        NaN               NaN               NaN
# 7                        NaN               NaN               NaN
#
#   location.region  geocodes.drop_off.latitude  geocodes.drop_off.longitude  \
# 0             NaN                         NaN                          NaN
# 1             NaN                         NaN                          NaN
# 2             NaN                         NaN                          NaN
# 3             NaN                         NaN                          NaN
# 4             NaN                         NaN                          NaN
# 5             NaN                         NaN                          NaN
# 6             NaN                         NaN                          NaN
# 7             NaN                         NaN                          NaN
#
#   location.address_extended
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
merged_df.head()
# Out:
#    empty_slots  free_bikes                                id   latitude  \
# 0          0.0         0.0  9be01b509184baee960fcffa4f1425d3  45.158664
# 1          0.0         0.0  2eb2a00e80e5d6fee19b932294a08927  45.147505
# 2          0.0         0.0  f2703a28d2f9f3a0e4078867966d4536  45.162056
# 3          0.0         0.0  2fd7039e15452a7a09b5ddca816a6375  45.157558
# 4          8.0         0.0  a97d2eb0b413d91a627e8e661356471b  45.153567
#
#    longitude_x           name_x                    timestamp  extra.number  \
# 0    10.783719  Stazione FF.SS.  2023-08-02T22:51:07.196000Z           1.0
# 1    10.795176     Porta Cerese  2023-08-02T22:51:07.197000Z           2.0
# 2    10.811605      Campo Canoa  2023-08-02T22:51:07.197000Z           3.0
# 3    10.794851      Castiglioni  2023-08-02T22:51:07.197000Z           4.0
# 4    10.797891        Anconetta  2023-08-02T22:51:07.197000Z           5.0
#
#    extra.reviews  extra.score extra.status extra.uid fsq_id categories chains  \
# 0            7.0          3.7      offline      1310    NaN        NaN    NaN
# 1            1.0          1.0      offline      1311    NaN        NaN    NaN
# 2            1.0          1.0      offline      1312    NaN        NaN    NaN
# 3            1.0          1.0      offline      1313    NaN        NaN    NaN
# 4            1.0          1.0      offline      1314    NaN        NaN    NaN
#
#    distance link name_y timezone  longitude_y  geocodes.roof.latitude  \
# 0       NaN  NaN    NaN      NaN          NaN                     NaN
# 1       NaN  NaN    NaN      NaN          NaN                     NaN
# 2       NaN  NaN    NaN      NaN          NaN                     NaN
# 3       NaN  NaN    NaN      NaN          NaN                     NaN
# 4       NaN  NaN    NaN      NaN          NaN                     NaN
#
#    geocodes.roof.longitude location.address location.admin_region  \
# 0                      NaN              NaN                   NaN
# 1                      NaN              NaN                   NaN
# 2                      NaN              NaN                   NaN
# 3                      NaN              NaN                   NaN
# 4                      NaN              NaN                   NaN
#
#   location.country location.cross_street location.formatted_address  \
# 0              NaN                   NaN                        NaN
# 1              NaN                   NaN                        NaN
# 2              NaN                   NaN                        NaN
# 3              NaN                   NaN                        NaN
# 4              NaN                   NaN                        NaN
#
#   location.locality location.postcode location.region  \
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# 4               NaN               NaN             NaN
#
#    geocodes.drop_off.latitude  geocodes.drop_off.longitude  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#   location.address_extended
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 0 to 17
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   empty_slots                  8 non-null      float64
#  1   free_bikes                   8 non-null      float64
#  2   id                           8 non-null      object
#  3   latitude                     18 non-null     float64
#  4   longitude_x                  8 non-null      float64
#  5   name_x                       8 non-null      object
#  6   timestamp                    8 non-null      object
#  7   extra.number                 8 non-null      float64
#  8   extra.reviews                8 non-null      float64
#  9   extra.score                  8 non-null      float64
#  10  extra.status                 8 non-null      object
#  11  extra.uid                    8 non-null      object
#  12  fsq_id                       10 non-null     object
#  13  categories                   10 non-null     object
#  14  chains                       10 non-null     object
#  15  distance                     10 non-null     float64
#  16  link                         10 non-null     object
#  17  name_y                       10 non-null     object
#  18  timezone                     10 non-null     object
#  19  longitude_y                  10 non-null     float64
#  20  geocodes.roof.latitude       9 non-null      float64
#  21  geocodes.roof.longitude      9 non-null      float64
#  22  location.address             10 non-null     object
#  23  location.admin_region        10 non-null     object
#  24  location.country             10 non-null     object
#  25  location.cross_street        10 non-null     object
#  26  location.formatted_address   10 non-null     object
#  27  location.locality            10 non-null     object
#  28  location.postcode            10 non-null     object
#  29  location.region              10 non-null     object
#  30  geocodes.drop_off.latitude   7 non-null      float64
#  31  geocodes.drop_off.longitude  7 non-null      float64
#  32  location.address_extended    2 non-null      object
# dtypes: float64(13), object(20)
# memory usage: 4.8+ KB

# %%
merged_df.shape
# Out:
# (18, 33)

# %%
merged_df.describe()
# Out:
#        empty_slots  free_bikes   latitude  longitude_x  extra.number  \
# count     8.000000         8.0  18.000000     8.000000       8.00000
# mean      1.000000         0.0  45.157269    10.794880       4.50000
# std       2.828427         0.0   0.003684     0.008578       2.44949
# min       0.000000         0.0  45.147505    10.783719       1.00000
# 25%       0.000000         0.0  45.157246    10.789420       2.75000
# 50%       0.000000         0.0  45.157781    10.795014       4.50000
# 75%       0.000000         0.0  45.158881    10.798101       6.25000
# max       8.000000         0.0  45.162355    10.811605       8.00000
#
#        extra.reviews  extra.score    distance  longitude_y  \
# count        8.00000     8.000000   10.000000    10.000000
# mean         2.12500     1.700000  238.900000    10.784622
# std          2.10017     1.067708  175.213806     0.003438
# min          1.00000     1.000000   25.000000    10.777163
# 25%          1.00000     1.000000  130.500000    10.783257
# 50%          1.00000     1.000000  165.000000    10.784930
# 75%          2.25000     2.225000  344.000000    10.785484
# max          7.00000     3.700000  536.000000    10.789726
#
#        geocodes.roof.latitude  geocodes.roof.longitude  \
# count                9.000000                 9.000000
# mean                45.158256                10.785451
# std                  0.001133                 0.002360
# min                 45.156465                10.782667
# 25%                 45.157646                10.784560
# 50%                 45.158101                10.785125
# 75%                 45.158954                10.785574
# max                 45.160319                10.789726
#
#        geocodes.drop_off.latitude  geocodes.drop_off.longitude
# count                    7.000000                     7.000000
# mean                    45.157963                    10.784942
# std                      0.000902                     0.001994
# min                     45.156605                    10.782567
# 25%                     45.157413                    10.783780
# 50%                     45.158014                    10.785051
# 75%                     45.158611                    10.785433
# max                     45.159074                    10.788550

# %%
import matplotlib.pyplot as plt

# Create Figure and Axes objects with which to do your plotting
fig, ax = plt.subplots()

# Plot the data using one of Matplotlib's plotting functions
ax.hist(merged_df['extra.score'])

# Customize other aspects of the plot
ax.set_title('Histogram of extra.score')
ax.set_xlabel('extra.score')
ax.set_ylabel('counts')

# Display the plot
plt.show()

# %%
import seaborn as sns

sns.set_theme(context = 'talk',     # recomend   context = 'talk'
              style = 'darkgrid',
              palette = 'deep',         # colorblind
              font = 'sans-serif',
              font_scale = 1
             ) # this will affect both sns and plt

# you can also set a figure size that will affect all sns plots in your notebook
#sns.set(rc={"figure.figsize":(10, 6)})

#seaborn histogram
sns.histplot(data=merged_df, x="extra.reviews", bins=30)       # dont have to have to make a figure or subplot when using seaborn

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(19, 10))

#matplotlib
axes[0,0].hist(merged_df['extra.score'])
axes[0,0].set_title('[Matplotlib] Histogram of extra.score')

axes[0,1].boxplot(merged_df['extra.score'])
axes[0,1].set_title('[Matplotlib] Box-Plot of extra.score')

#seaborn
sns.histplot(ax=axes[1,0], data=merged_df, x="extra.reviews")
axes[1,0].set_title('[Seaborn] Histogram of extr.reviews')

sns.boxplot(ax=axes[1,1], data=merged_df, y="extra.reviews")
axes[1,1].set_title('[Seaborn] Box-Plot of extra.reviews')

plt.show()

# %%
sns.scatterplot(data=merged_df, 
                x="extra.score", 
                y="extra.number",
                alpha = 0.7)
plt.suptitle("Scatter Plot Comparing score to number")
plt.show()

# %%
merged_df.corr() #to check if there is a correlation
# Out:
# C:\Users\MizCeey\AppData\Local\Temp\ipykernel_26496\35518180.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merged_df.corr() #to check if there is a correlation
#                              empty_slots  free_bikes  latitude  longitude_x  \
# empty_slots                     1.000000         NaN -0.195256     0.141832
# free_bikes                           NaN         NaN       NaN          NaN
# latitude                       -0.195256         NaN  1.000000     0.394618
# longitude_x                     0.141832         NaN  0.394618     1.000000
# extra.number                    0.082479         NaN -0.018932    -0.074007
# extra.reviews                  -0.216444         NaN  0.364165    -0.506313
# extra.score                    -0.264906         NaN  0.386895    -0.545660
# distance                             NaN         NaN  0.221291          NaN
# longitude_y                          NaN         NaN  0.676051          NaN
# geocodes.roof.latitude               NaN         NaN  1.000000          NaN
# geocodes.roof.longitude              NaN         NaN  0.736132          NaN
# geocodes.drop_off.latitude           NaN         NaN  0.990556          NaN
# geocodes.drop_off.longitude          NaN         NaN  0.540018          NaN
#
#                              extra.number  extra.reviews  extra.score  \
# empty_slots                      0.082479      -0.216444    -0.264906
# free_bikes                            NaN            NaN          NaN
# latitude                        -0.018932       0.364165     0.386895
# longitude_x                     -0.074007      -0.506313    -0.545660
# extra.number                     1.000000      -0.402661    -0.223953
# extra.reviews                   -0.402661       1.000000     0.879173
# extra.score                     -0.223953       0.879173     1.000000
# distance                              NaN            NaN          NaN
# longitude_y                           NaN            NaN          NaN
# geocodes.roof.latitude                NaN            NaN          NaN
# geocodes.roof.longitude               NaN            NaN          NaN
# geocodes.drop_off.latitude            NaN            NaN          NaN
# geocodes.drop_off.longitude           NaN            NaN          NaN
#
#                              distance  longitude_y  geocodes.roof.latitude  \
# empty_slots                       NaN          NaN                     NaN
# free_bikes                        NaN          NaN                     NaN
# latitude                     0.221291     0.676051                1.000000
# longitude_x                       NaN          NaN                     NaN
# extra.number                      NaN          NaN                     NaN
# extra.reviews                     NaN          NaN                     NaN
# extra.score                       NaN          NaN                     NaN
# distance                     1.000000    -0.004842                0.511262
# longitude_y                 -0.004842     1.000000                0.736132
# geocodes.roof.latitude       0.511262     0.736132                1.000000
# geocodes.roof.longitude      0.864597     1.000000                0.736132
# geocodes.drop_off.latitude   0.121977     0.498468                0.990556
# geocodes.drop_off.longitude  0.817518     0.999133                0.540018
#
#                              geocodes.roof.longitude  \
# empty_slots                                      NaN
# free_bikes                                       NaN
# latitude                                    0.736132
# longitude_x                                      NaN
# extra.number                                     NaN
# extra.reviews                                    NaN
# extra.score                                      NaN
# distance                                    0.864597
# longitude_y                                 1.000000
# geocodes.roof.latitude                      0.736132
# geocodes.roof.longitude                     1.000000
# geocodes.drop_off.latitude                  0.498468
# geocodes.drop_off.longitude                 0.999133
#
#                              geocodes.drop_off.latitude  \
# empty_slots                                         NaN
# free_bikes                                          NaN
# latitude                                       0.990556
# longitude_x                                         NaN
# extra.number                                        NaN
# extra.reviews                                       NaN
# extra.score                                         NaN
# distance                                       0.121977
# longitude_y                                    0.498468
# geocodes.roof.latitude                         0.990556
# geocodes.roof.longitude                        0.498468
# geocodes.drop_off.latitude                     1.000000
# geocodes.drop_off.longitude                    0.495350
#
#                              geocodes.drop_off.longitude
# empty_slots                                          NaN
# free_bikes                                           NaN
# latitude                                        0.540018
# longitude_x                                          NaN
# extra.number                                         NaN
# extra.reviews                                        NaN
# extra.score                                          NaN
# distance                                        0.817518
# longitude_y                                     0.999133
# geocodes.roof.latitude                          0.540018
# geocodes.roof.longitude                         0.999133
# geocodes.drop_off.latitude                      0.495350
# geocodes.drop_off.longitude                     1.000000

# %%
sns.heatmap(merged_df.corr())
# Out:
# C:\Users\MizCeey\AppData\Local\Temp\ipykernel_26496\3699120657.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(merged_df.corr())
# <Axes: >

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
import sqlite3
from sqlite3 import Error

def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %% [markdown]
# Look at the data before and after the join to validate your data.
