# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
# imports
import requests
import os
import pandas as pd
apikey = os.environ['FOURSQUARE_API']
from pprint import pprint

# %%
city_bike_df = pd.read_csv('../data/city_bikes_output_file.csv')
city_bike_df
# Out:
#                             name   latitude  longitude  empty_slots  \
# 0      Queen St E / Woodward Ave  43.665269 -79.319796            5
# 1    Primrose Ave / Davenport Rd  43.671420 -79.445947           15
# 2      Queen St. E / Rhodes Ave.  43.666224 -79.317693           10
# 3           Bond St / Queen St E  43.653236 -79.376716           22
# 4       Church St / Alexander St  43.663722 -79.380288            4
# ..                           ...        ...        ...          ...
# 680  Avenue Rd / Macpherson Ave   43.677944 -79.398363            9
# 681               Princes' Gates  43.634565 -79.409161            0
# 682     Dufferin St / Queen St W  43.643097 -79.428756            0
# 683         Bay St / Dundas St W  43.655351 -79.383460            7
# 684          Shaw St / King St W  43.641256 -79.415030            1
#
#      free_bikes
# 0            12
# 1             0
# 2            13
# 3             1
# 4            23
# ..          ...
# 680           4
# 681          15
# 682          15
# 683          19
# 684          14
#
# [685 rows x 5 columns]

# %%
# finding duplicate values
city_bike_df.duplicated().value_counts()
# Out:
# False    685
# dtype: int64

# %%
yelp_df = pd.read_csv('../data/yelp_data.csv')
yelp_df
# Out:
#                                  name  review_count  rating price  \
# 0                    Richmond Station           904     4.5   $$$
# 1        Mogouyan Hand-Pulled Noodles            65     4.5    $$
# 2                     The Rabbit Hole            35     4.0   NaN
# 3                            Hana Don            14     4.5   NaN
# 4           Pai Northern Thai Kitchen          3470     4.5    $$
# 5                             Katsuya           496     4.5    $$
# 6      Gyubee Japanese Grill - Dundas           210     4.5   $$$
# 7                          Chefs Hall           320     4.0    $$
# 8           Hendriks Restaurant & Bar           115     4.0   $$$
# 9                         The Senator           492     4.0    $$
# 10                   Haidilao Hot Pot            32     5.0   NaN
# 11                     11:59 Bar:Café             4     4.0   NaN
# 12                       Trios Bistro            22     4.0    $$
# 13                          King Taps           400     4.0    $$
# 14       Holy Cow Japanese Steakhouse           157     4.5   $$$
# 15                  Grandma Loves You            11     4.5   NaN
# 16                   Cactus Club Cafe           601     4.0    $$
# 17  The Queen And Beaver Public House           412     4.0    $$
# 18                        Moon Palace            60     4.0   NaN
# 19                Liko's Hawaiian BBQ             4     4.0   NaN
#
#                  location   latitude  longitude
# 0     1 Richmond Street W  43.651373 -79.379285
# 1         124 Dundas St W  43.655730 -79.384490
# 2    21 Adelaide Street W  43.649950 -79.379760
# 3     128 Dundas Street W  43.655720 -79.384540
# 4        18 Duncan Street  43.647840 -79.388720
# 5     66 Gerrard Street E  43.659950 -79.378820
# 6         157 Dundas St W  43.655143 -79.385763
# 7   111 Richmond Street W  43.650352 -79.383795
# 8        218 Yonge Street  43.653501 -79.380048
# 9     249 Victoria Street  43.655740 -79.378960
# 10       237 Yonge Street  43.654633 -79.379839
# 11   70 Temperance Street  43.650485 -79.381991
# 12             525 Bay St  43.654573 -79.383023
# 13      100 King Street W  43.648638 -79.381744
# 14    254 Queen Street  W  43.649930 -79.391450
# 15  111 Richmond Street W  43.650302 -79.383952
# 16   77 Adelaide Street W  43.649504 -79.382518
# 17          35 Elm Street  43.657340 -79.383340
# 18     40 Dundas Street W  43.656195 -79.382403
# 19                    NaN  43.651600 -79.383310

# %%
# finding duplicate values
yelp_df.duplicated().value_counts()
# Out:
# False    20
# dtype: int64

# %%
merged_df = pd.merge(city_bike_df, yelp_df, on='name', how='outer')
merged_df
# Out:
#                                   name  latitude_x  longitude_x  empty_slots  \
# 0            Queen St E / Woodward Ave   43.665269   -79.319796          5.0
# 1          Primrose Ave / Davenport Rd   43.671420   -79.445947         15.0
# 2            Queen St. E / Rhodes Ave.   43.666224   -79.317693         10.0
# 3                 Bond St / Queen St E   43.653236   -79.376716         22.0
# 4             Church St / Alexander St   43.663722   -79.380288          4.0
# ..                                 ...         ...          ...          ...
# 700                  Grandma Loves You         NaN          NaN          NaN
# 701                   Cactus Club Cafe         NaN          NaN          NaN
# 702  The Queen And Beaver Public House         NaN          NaN          NaN
# 703                        Moon Palace         NaN          NaN          NaN
# 704                Liko's Hawaiian BBQ         NaN          NaN          NaN
#
#      free_bikes  review_count  rating price               location  \
# 0          12.0           NaN     NaN   NaN                    NaN
# 1           0.0           NaN     NaN   NaN                    NaN
# 2          13.0           NaN     NaN   NaN                    NaN
# 3           1.0           NaN     NaN   NaN                    NaN
# 4          23.0           NaN     NaN   NaN                    NaN
# ..          ...           ...     ...   ...                    ...
# 700         NaN          11.0     4.5   NaN  111 Richmond Street W
# 701         NaN         601.0     4.0    $$   77 Adelaide Street W
# 702         NaN         412.0     4.0    $$          35 Elm Street
# 703         NaN          60.0     4.0   NaN     40 Dundas Street W
# 704         NaN           4.0     4.0   NaN                    NaN
#
#      latitude_y  longitude_y
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# ..          ...          ...
# 700   43.650302   -79.383952
# 701   43.649504   -79.382518
# 702   43.657340   -79.383340
# 703   43.656195   -79.382403
# 704   43.651600   -79.383310
#
# [705 rows x 11 columns]

# %% [markdown]
# I tried to do different joins but it was not giving a good database, so ended up using the outer join with some NaN values. Also tried to remove the NaN values but it ended up removing my data, additionally i tried to update NaN values with mean but for yelp data which is small, the mean value is not a reflection of the true data base

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
merged_df.head()
# Out:
#                           name  latitude_x  longitude_x  empty_slots  \
# 0    Queen St E / Woodward Ave   43.665269   -79.319796          5.0
# 1  Primrose Ave / Davenport Rd   43.671420   -79.445947         15.0
# 2    Queen St. E / Rhodes Ave.   43.666224   -79.317693         10.0
# 3         Bond St / Queen St E   43.653236   -79.376716         22.0
# 4     Church St / Alexander St   43.663722   -79.380288          4.0
#
#    free_bikes  review_count  rating price location  latitude_y  longitude_y
# 0        12.0           NaN     NaN   NaN      NaN         NaN          NaN
# 1         0.0           NaN     NaN   NaN      NaN         NaN          NaN
# 2        13.0           NaN     NaN   NaN      NaN         NaN          NaN
# 3         1.0           NaN     NaN   NaN      NaN         NaN          NaN
# 4        23.0           NaN     NaN   NaN      NaN         NaN          NaN

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 704
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          705 non-null    object
#  1   latitude_x    685 non-null    float64
#  2   longitude_x   685 non-null    float64
#  3   empty_slots   685 non-null    float64
#  4   free_bikes    685 non-null    float64
#  5   review_count  20 non-null     float64
#  6   rating        20 non-null     float64
#  7   price         13 non-null     object
#  8   location      19 non-null     object
#  9   latitude_y    20 non-null     float64
#  10  longitude_y   20 non-null     float64
# dtypes: float64(8), object(3)
# memory usage: 66.1+ KB

# %%
merged_df.shape
# Out:
# (705, 11)

# %%
# remove unwanted columns
merged_df = merged_df.drop('longitude_y', axis=1)

# %%
merged_df.head()
# Out:
#                           name  latitude_x  longitude_x  empty_slots  \
# 0    Queen St E / Woodward Ave   43.665269   -79.319796          5.0
# 1  Primrose Ave / Davenport Rd   43.671420   -79.445947         15.0
# 2    Queen St. E / Rhodes Ave.   43.666224   -79.317693         10.0
# 3         Bond St / Queen St E   43.653236   -79.376716         22.0
# 4     Church St / Alexander St   43.663722   -79.380288          4.0
#
#    free_bikes  review_count  rating price location  latitude_y
# 0        12.0           NaN     NaN   NaN      NaN         NaN
# 1         0.0           NaN     NaN   NaN      NaN         NaN
# 2        13.0           NaN     NaN   NaN      NaN         NaN
# 3         1.0           NaN     NaN   NaN      NaN         NaN
# 4        23.0           NaN     NaN   NaN      NaN         NaN

# %%
# remove unwanted columns
merged_df = merged_df.drop('latitude_y', axis=1)

# %%
merged_df.head()
# Out:
#                           name  latitude_x  longitude_x  empty_slots  \
# 0    Queen St E / Woodward Ave   43.665269   -79.319796          5.0
# 1  Primrose Ave / Davenport Rd   43.671420   -79.445947         15.0
# 2    Queen St. E / Rhodes Ave.   43.666224   -79.317693         10.0
# 3         Bond St / Queen St E   43.653236   -79.376716         22.0
# 4     Church St / Alexander St   43.663722   -79.380288          4.0
#
#    free_bikes  review_count  rating price location
# 0        12.0           NaN     NaN   NaN      NaN
# 1         0.0           NaN     NaN   NaN      NaN
# 2        13.0           NaN     NaN   NaN      NaN
# 3         1.0           NaN     NaN   NaN      NaN
# 4        23.0           NaN     NaN   NaN      NaN

# %%
merged_df.describe()
# Out:
#        latitude_x  longitude_x  empty_slots  free_bikes  review_count  \
# count  685.000000   685.000000   685.000000  685.000000     20.000000
# mean    43.667737   -79.391337     9.315328    8.632117    391.200000
# std      0.030158     0.059826     7.343881    6.909745    766.800365
# min     43.588077   -79.544491     0.000000    0.000000      4.000000
# 25%     43.648928   -79.425000     3.000000    3.000000     29.500000
# 50%     43.661667   -79.392125     9.000000    7.000000    136.000000
# 75%     43.679188   -79.366470    14.000000   14.000000    432.000000
# max     43.788319   -79.123505    39.000000   33.000000   3470.000000
#
#           rating
# count  20.000000
# mean    4.250000
# std     0.303488
# min     4.000000
# 25%     4.000000
# 50%     4.000000
# 75%     4.500000
# max     5.000000

# %% [markdown]
# the average number of free bikes per station is about 8.6 and average rating is 4.25

# %%
import matplotlib.pyplot as plt

# Create Figure and Axes objects with which to do your plotting
fig, ax = plt.subplots()

# Plot the data using one of Matplotlib's plotting functions
ax.hist(merged_df['empty_slots'])

# Customize other aspects of the plot
ax.set_title('Histogram of empty_slots')
ax.set_xlabel('empty_slots')
ax.set_ylabel('counts')

# Display the plot
plt.show()

# %%
import seaborn as sns

sns.set_theme(context = 'talk',     # recomend   context = 'talk'
              style = 'darkgrid',
              palette = 'deep',         # colorblind
              font = 'sans-serif',
              font_scale = 1
             ) # this will affect both sns and plt

# you can also set a figure size that will affect all sns plots in your notebook
#sns.set(rc={"figure.figsize":(10, 6)})

#seaborn histogram
sns.histplot(data=merged_df, x="free_bikes", bins=30)       # dont have to have to make a figure or subplot when using seaborn

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(19, 10))

#matplotlib
axes[0,0].hist(merged_df['empty_slots'])
axes[0,0].set_title('[Matplotlib] Histogram of empty_slots')

axes[0,1].boxplot(merged_df['empty_slots'])
axes[0,1].set_title('[Matplotlib] Box-Plot of empty_slots')

#seaborn
sns.histplot(ax=axes[1,0], data=merged_df, x="free_bikes")
axes[1,0].set_title('[Seaborn] Histogram of free_bikes')

sns.boxplot(ax=axes[1,1], data=merged_df, y="free_bikes")
axes[1,1].set_title('[Seaborn] Box-Plot of free_bikes')

plt.show()

# %%
merged_df.corr() #to check if there is a correlation
# Out:
# C:\Users\MizCeey\AppData\Local\Temp\ipykernel_22252\35518180.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merged_df.corr() #to check if there is a correlation
#               latitude_x  longitude_x  empty_slots  free_bikes  review_count  \
# latitude_x      1.000000     0.364170     0.252552   -0.374687           NaN
# longitude_x     0.364170     1.000000     0.020264   -0.042641           NaN
# empty_slots     0.252552     0.020264     1.000000   -0.629216           NaN
# free_bikes     -0.374687    -0.042641    -0.629216    1.000000           NaN
# review_count         NaN          NaN          NaN         NaN      1.000000
# rating               NaN          NaN          NaN         NaN      0.167248
#
#                 rating
# latitude_x         NaN
# longitude_x        NaN
# empty_slots        NaN
# free_bikes         NaN
# review_count  0.167248
# rating        1.000000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(merged_df.corr(), annot=True, cmap="tab20c")
# Out:
# C:\Users\MizCeey\AppData\Local\Temp\ipykernel_22252\2822260574.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(merged_df.corr(), annot=True, cmap="tab20c")
# <Axes: >

# %%
sns.pairplot(merged_df)
plt.show()
#to view and compare many distributions at the same time

# %%
# Write the DataFrame to a CSV file
merged_df.to_csv("../data/merged_data.csv", index=False)

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
import sqlite3
from sqlite3 import Error

def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %%
connection = create_connection("sm_app.sqlite")
# Out:
# Connection to SQLite DB successful

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 704
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          705 non-null    object
#  1   latitude_x    685 non-null    float64
#  2   longitude_x   685 non-null    float64
#  3   empty_slots   685 non-null    float64
#  4   free_bikes    685 non-null    float64
#  5   review_count  20 non-null     float64
#  6   rating        20 non-null     float64
#  7   price         13 non-null     object
#  8   location      19 non-null     object
# dtypes: float64(6), object(3)
# memory usage: 55.1+ KB

# %%
create_bike_table = """
CREATE TABLE IF NOT EXISTS bike(
 "name" TEXT NOT NULL,
  name TEXT PRIMARY KEY,
  latitude_x FLOAT,
  longitude_x FLOAT,
  empty_slots FLOAT,
  free_bikes FLOAT,
  review_count FLOAT,
  rating FLOAT,
  price TEXT,
  location TEXT
  );
"""

# %%
execute_query(connection, create_bike_table)
# Out:
# Query executed successfully

# %%
merged_df.to_sql('bike', con=connection, if_exists="replace")
# Out:
# 705

# %%
select_bike = "SELECT * FROM bike"
bike = execute_query(connection, select_bike)
# Out:
# Query executed successfully
